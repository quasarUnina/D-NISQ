# %% [markdown]
# # Distributed Grover's Search
# ____
#
#
# This python notebook is useful to exploit a distributed version of the<b> Grover's algorithm </b> implemented according the D-NISQ reference model proposed in the article "Distributed Noisy-Intermediate Scale Quantum: an Application to Grover-based Algorithms" by Giovanni Acampora, Ferdinando Di Martino, Alfredo Massa, Roberto Schiattarella, Autilia Vitiello submitted to the journal Information Fusion (Elsevier).
#
# For more detail about the  Grover's Algorithn (GA) and its distributed version on the D-NISQ architecture, please, refer to the aforementioned paper.
#
# Let us start importing the required libreries.

# %%
from threading import *
from concurrent.futures import *
from datetime import datetime
from statistics import mean

from GroverCircuitBuilder import *
from QuantumComputing import *
from DistributedGroverAlgorithm_1 import *
dateandtime = datetime.now().strftime("%d.%m.%Y  %H.%M.%S")

# %% [markdown]
# After importing required libraries, it is necessary to set the backend to be used for running GA. The following parameters need to be set:
#
# - SIMULATION : True for simulators, False for real quantum computers;
#
# - NOISE : True for simulation with a noise model, False for ideal simulation;
#
# - BACKEND: Specify the backend to use. If it is a fake backend use the notation FakeProcessor() or it is a real device indicate the name as string;
#
# - DIFFERENT_BACKENDS: True to assign different backends to different sub-problems. False to use the same backend for all the sub-problems;
#
# - SHOTS: Number of shots in each backend;
# - RUN: number of executions of the algorithm;

# %%
# BACKEND SETTINGS ----------------------------------------------------------------------------------------------------

SIMULATION = True                       
NOISE = False                             
BACKEND = FakeAlmaden()                  # EXAMPLE: FakeValencia() for mock backend, 'ibmq_valencia' for real device
DIFFERENT_BACKENDS = False               
SHOTS = 8192
RUN = 5

# %% [markdown]
# Moreover, it is necessary some parameters to store results:
#  - REPORT_FILE : set True to create a .txt log file;
#  - FILE_PATH : specify the log file path;
#  - FILE_NAME : specify the log file name.

# %%
# GENERAL SETTINGS ----------------------------------------------------------------------------------------------------

                                  
REPORT_FILE = False                     
FILE_PATH = f"C:\\"
FILE_NAME = f"Report_{dateandtime}.txt"

# %% [markdown]
# Provide informations about the database on which execute the Grover's Search:
#
#   - N : database size. (It must be a power of 2);
#   - WINNER : winner item. Please, note that it is an arbitrary variable;
#   - OTHER : non-winner strings to fill the database. Also this variable is arbitrary;
#   - WINNER_INDEX : location in the database of the winner item. (arbitrary).

# %%
# DATABASE SETTINGS ---------------------------------------------------------------------------------------------------

N = 128                                    
WINNER = "1111111111"                    
OTHER = "0000000000"                     
WINNER_INDEX = 10

# %% [markdown]
# Set the parameters for the D-Nisq architecture:
#
# - NUMBER_OF_SUBPROBLEMS: the number of sub-problems created by the <i> Decomposition Layer </i>

# %%
# PARALLELISM SETTINGS ------------------------------------------------------------------------------------------------

NUMBER_OF_SUBPROBLEMS = 32               # Set 1 to perform a standard search without parallelism

# %% [markdown]
# Finally, set the parameters for the Grover's algorithms:
#
# - MANUAL_ITERATIONS: an integer indicating the number of iterations of each Grover's algorithm
# - HISTOGRAMS: True to plot counts histograms at the end of each Grover search

# %%
# GROVER'S ALGORITHM SETTINGS -----------------------------------------------------------------------------------------

MANUAL_ITERATIONS = 1                
HISTOGRAMS = False

# %% [markdown]
# Run the following cell to import the backend, build the database and the quantum circuit useful to implement the Grover's search in each thread.

# %%
# DISTRIBUTED GROVER'S SEARCH -----------------------------------------------------------------------------------------

max_times = []
successes = 0
sub_N = int(N / NUMBER_OF_SUBPROBLEMS)

assert N % NUMBER_OF_SUBPROBLEMS == 0, "Please choose the number of subproblems as a divisor of N."

sub_n = int(log(sub_N, 2))
THREADLOCK = Lock()

write_report(report_opening(dateandtime, RUN, N, NUMBER_OF_SUBPROBLEMS, sub_N, sub_n, MANUAL_ITERATIONS, SHOTS,
                           SIMULATION, NOISE, DIFFERENT_BACKENDS, BACKEND), REPORT_FILE, FILE_PATH + FILE_NAME)

if SIMULATION and NOISE:
    print("\nCreating a mock-backend list...")
    MOCK_BACKEND_LIST = [QasmSimulator.from_backend(BACKEND) for _ in range(NUMBER_OF_SUBPROBLEMS)]
    print("\nMock-backend list created.")
else:
    MOCK_BACKEND_LIST = None

if DIFFERENT_BACKENDS:
    backend_list, backend_information = ask_for_backends(NUMBER_OF_SUBPROBLEMS)
    write_report(backend_information, REPORT_FILE, FILE_PATH + FILE_NAME)

database = create_database(N, WINNER, OTHER, WINNER_INDEX)
sub_databases, winner_coordinates = create_sub_databases(database, NUMBER_OF_SUBPROBLEMS, sub_N, WINNER)
sub_basis = create_sub_basis(NUMBER_OF_SUBPROBLEMS, sub_N, sub_n)
sub_oracles = create_sub_oracles(NUMBER_OF_SUBPROBLEMS, sub_N, winner_coordinates)
sub_diffusers = create_sub_diffusers(NUMBER_OF_SUBPROBLEMS, sub_N, sub_basis)

sub_grover_circuits = [grover_circuit_builder(sub_N, sub_n, sub_oracles[i], sub_diffusers[i], MANUAL_ITERATIONS)
                       for i in range(NUMBER_OF_SUBPROBLEMS)]
# Out:
# ___________________________________________________________
#
# DISTRIBUTED GROVER'S ALGORITHM
# Report 09.11.2021  16.43.38
#
# Number of runs: 5
#
# INPUT:
# Number of items in main database: 128
# Number of subproblems: 32
# Number of items per sub-database: 4
# Number of qubits per sub-problem: 2
# Grover iterations per sub-circuit: 1
# Shots per sub-problem: 8192
#
# QUANTUM COMPUTER: ideal Qasm Simulator

# %% [markdown]
# Execute the Distributed Grover's Search for a number of runs indicated in the aforementioned variable RUN.

# %%
for run in range(RUN):

    run_information = f"\n\n\n------------------------ RUN {run+1} -----------------------------\n"
    write_report(run_information, REPORT_FILE, FILE_PATH + FILE_NAME)                    
    results = distributed_grover_search(NUMBER_OF_SUBPROBLEMS, sub_grover_circuits, SIMULATION, NOISE, SHOTS, BACKEND,
                                        MOCK_BACKEND_LIST)

    sub_counts, counts_information = get_counts(results, NUMBER_OF_SUBPROBLEMS)
    write_report(counts_information, REPORT_FILE, FILE_PATH + FILE_NAME)

    execution_times, max_time, times_information = get_times(results, NUMBER_OF_SUBPROBLEMS)
    max_times.append(max_time)
    write_report(times_information, REPORT_FILE, FILE_PATH + FILE_NAME)

    success, success_information = verify_success(NUMBER_OF_SUBPROBLEMS, sub_N, sub_n, sub_counts, WINNER_INDEX)
    write_report(success_information, REPORT_FILE, FILE_PATH + FILE_NAME)

    if success:
        successes += 1

    write_report(current_situation(run + 1, max_times, successes), REPORT_FILE, FILE_PATH + FILE_NAME)

    if HISTOGRAMS:
        show_data(NUMBER_OF_SUBPROBLEMS, sub_counts)

write_report("\n\n\n\n", REPORT_FILE, FILE_PATH + FILE_NAME)
# Out:
# ------------------------ RUN 1 -----------------------------
#
# Thread 1 started
#
#
# Thread 1: JobStatus.RUNNING
#
# Thread 1: JobStatus.DONE
# Thread 2 started
#
#
# Thread 2: JobStatus.RUNNING
#
# Thread 2: JobStatus.DONE
# Thread 3 started
#
#
# Thread 3: JobStatus.DONE
# Thread 4 started
#
#
# Thread 4: JobStatus.RUNNING
#
# Thread 4: JobStatus.DONE
# Thread 5 started
#
#
# Thread 5: JobStatus.RUNNING
#
# Thread 5: JobStatus.DONE
# Thread 6 started
#
#
# Thread 6: JobStatus.RUNNING
#
# Thread 6: JobStatus.DONE
# Thread 7 started
#
#
# Thread 7: JobStatus.DONE
# Thread 8 started
#
#
# Thread 8: JobStatus.RUNNING
#
# Thread 8: JobStatus.DONE
# Thread 9 started
#
#
# Thread 9: JobStatus.RUNNING
#
# Thread 9: JobStatus.DONE
# Thread 10 started
#
# Thread 10: JobStatus.RUNNING
#
#
# Thread 10: JobStatus.DONE
# Thread 11 started
#
#
# Thread 11: JobStatus.RUNNING
#
# Thread 11: JobStatus.DONE
# Thread 12 started
#
#
# Thread 12: JobStatus.RUNNING
#
# Thread 12: JobStatus.DONE
# Thread 13 started
#
#
# Thread 13: JobStatus.RUNNING
#
# Thread 13: JobStatus.DONE
# Thread 14 started
#
#
# Thread 14: JobStatus.RUNNING
#
# Thread 14: JobStatus.DONE
# Thread 15 started
#
#
# Thread 15: JobStatus.RUNNING
#
# Thread 15: JobStatus.DONE
# Thread 16 started
#
#
# Thread 16: JobStatus.RUNNING
#
# Thread 16: JobStatus.DONE
# Thread 17 started
#
#
# Thread 17: JobStatus.RUNNING
#
# Thread 17: JobStatus.DONE
# Thread 18 started
#
#
# Thread 18: JobStatus.RUNNING
#
# Thread 18: JobStatus.DONE
# Thread 19 started
#
#
# Thread 19: JobStatus.RUNNING
#
# Thread 19: JobStatus.DONE
# Thread 20 started
#
#
# Thread 20: JobStatus.DONE
# Thread 21 started
#
#
# Thread 21: JobStatus.RUNNING
#
# Thread 21: JobStatus.DONE
# Thread 22 started
#
#
# Thread 22: JobStatus.RUNNING
#
# Thread 22: JobStatus.DONE
# Thread 23 started
#
#
# Thread 23: JobStatus.RUNNING
#
# Thread 23: JobStatus.DONE
# Thread 24 started
#
#
# Thread 24: JobStatus.DONE
# Thread 25 started
#
#
# Thread 25: JobStatus.RUNNING
#
# Thread 25: JobStatus.DONE
# Thread 26 started
#
#
# Thread 26: JobStatus.RUNNING
#
# Thread 26: JobStatus.DONE
# Thread 27 started
#
#
# Thread 27: JobStatus.RUNNING
#
# Thread 27: JobStatus.DONE
# Thread 28 started
#
#
# Thread 28: JobStatus.RUNNING
#
# Thread 28: JobStatus.DONE
# Thread 29 started
#
# Thread 29: JobStatus.RUNNING
#
#
# Thread 29: JobStatus.DONE
#
# Thread 30: JobStatus.RUNNING
# Thread 30 started
#
#
# Thread 30: JobStatus.DONE
# Thread 31 started
#
#
# Thread 31: JobStatus.RUNNING
#
# Thread 31: JobStatus.DONE
# Thread 32 started
#
#
# Thread 32: JobStatus.DONE
#
# All threads are done.
#
# COUNTS:
# Thread 1: {'00': 2079, '01': 2135, '10': 1968, '11': 2010}
# Thread 2: {'00': 2054, '01': 1985, '10': 2087, '11': 2066}
# Thread 3: {'10': 8192}
# Thread 4: {'00': 2057, '01': 2086, '10': 2040, '11': 2009}
# Thread 5: {'00': 1947, '01': 2063, '10': 2083, '11': 2099}
# Thread 6: {'00': 2056, '01': 2098, '10': 2038, '11': 2000}
# Thread 7: {'00': 2077, '01': 2007, '10': 2048, '11': 2060}
# Thread 8: {'00': 1961, '01': 2078, '10': 2061, '11': 2092}
# Thread 9: {'00': 2106, '01': 2051, '10': 1950, '11': 2085}
# Thread 10: {'00': 2062, '01': 2033, '10': 2049, '11': 2048}
# Thread 11: {'00': 2121, '01': 2058, '10': 2024, '11': 1989}
# Thread 12: {'00': 2045, '01': 2024, '10': 2070, '11': 2053}
# Thread 13: {'00': 2037, '01': 2045, '10': 2029, '11': 2081}
# Thread 14: {'00': 2031, '01': 2025, '10': 2159, '11': 1977}
# Thread 15: {'00': 2117, '01': 2038, '10': 2005, '11': 2032}
# Thread 16: {'00': 2034, '01': 1968, '10': 2155, '11': 2035}
# Thread 17: {'00': 2151, '01': 2044, '10': 2011, '11': 1986}
# Thread 18: {'00': 2014, '01': 1985, '10': 2068, '11': 2125}
# Thread 19: {'00': 2053, '01': 1998, '10': 2082, '11': 2059}
# Thread 20: {'00': 2059, '01': 2075, '10': 2008, '11': 2050}
# Thread 21: {'00': 2059, '01': 1986, '10': 2045, '11': 2102}
# Thread 22: {'00': 2062, '01': 2072, '10': 2032, '11': 2026}
# Thread 23: {'00': 2077, '01': 2120, '10': 2032, '11': 1963}
# Thread 24: {'00': 2031, '01': 2018, '10': 2013, '11': 2130}
# Thread 25: {'00': 2028, '01': 2059, '10': 2031, '11': 2074}
# Thread 26: {'00': 2072, '01': 2008, '10': 1991, '11': 2121}
# Thread 27: {'00': 2131, '01': 2040, '10': 2004, '11': 2017}
# Thread 28: {'00': 2086, '01': 2078, '10': 2010, '11': 2018}
# Thread 29: {'00': 2008, '01': 2072, '10': 2086, '11': 2026}
# Thread 30: {'00': 2028, '01': 2070, '10': 2045, '11': 2049}
# Thread 31: {'00': 2141, '01': 2012, '10': 2077, '11': 1962}
# Thread 32: {'00': 2038, '01': 2031, '10': 2032, '11': 2091}
#
# EXECUTION TIMES:
# Thread 1: 0.09767580032348633 s
# Thread 2: 0.10090303421020508 s
# Thread 3: 0.07937908172607422 s
# Thread 4: 0.08441519737243652 s
# Thread 5: 0.09165310859680176 s
# Thread 6: 0.08385014533996582 s
# Thread 7: 0.0776357650756836 s
# Thread 8: 0.09495878219604492 s
# Thread 9: 0.09080839157104492 s
# Thread 10: 0.08767390251159668 s
# Thread 11: 0.08405494689941406 s
# Thread 12: 0.09167265892028809 s
# Thread 13: 0.08420896530151367 s
# Thread 14: 0.08019661903381348 s
# Thread 15: 0.08696913719177246 s
# Thread 16: 0.08391618728637695 s
# Thread 17: 0.08262109756469727 s
# Thread 18: 0.08883166313171387 s
# Thread 19: 0.08766293525695801 s
# Thread 20: 0.0785224437713623 s
# Thread 21: 0.08465409278869629 s
# Thread 22: 0.07791590690612793 s
# Thread 23: 0.09147930145263672 s
# Thread 24: 0.08205175399780273 s
# Thread 25: 0.09300756454467773 s
# Thread 26: 0.07875609397888184 s
# Thread 27: 0.07786107063293457 s
# Thread 28: 0.08425450325012207 s
# Thread 29: 0.08479952812194824 s
# Thread 30: 0.0838775634765625 s
# Thread 31: 0.09168386459350586 s
# Thread 32: 0.07976245880126953 s
#
# Longest execution time: 0.10090303421020508 s (in thread number 2)
#
# Winner item has been found in sub-problem number 3.
# Index in main database: 10.
# Expected index: 10.
#
# Grover's search has succeeded.
# ------------------------------------------------------------
# After 1 runs:
# Mean execution time: 0.10090303421020508 s
# Successes: 1
# Success rate: 100.0 %.
# ------------------------------------------------------------
#
#
#
# ------------------------ RUN 2 -----------------------------
#
# Thread 1 started
#
#
# Thread 1: JobStatus.RUNNING
#
# Thread 1: JobStatus.DONE
# Thread 2 started
#
#
# Thread 2: JobStatus.RUNNING
#
# Thread 2: JobStatus.DONE
# Thread 3 started
#
#
# Thread 3: JobStatus.RUNNING
#
# Thread 3: JobStatus.DONE
# Thread 4 started
#
#
# Thread 4: JobStatus.RUNNING
#
# Thread 4: JobStatus.DONE
# Thread 5 started
#
#
# Thread 5: JobStatus.RUNNING
#
# Thread 5: JobStatus.DONE
# Thread 6 started
#
#
# Thread 6: JobStatus.RUNNING
#
# Thread 6: JobStatus.DONE
# Thread 7 started
#
#
# Thread 7: JobStatus.RUNNING
#
# Thread 7: JobStatus.DONE
# Thread 8 started
#
#
# Thread 8: JobStatus.RUNNING
#
# Thread 8: JobStatus.DONE
# Thread 9 started
#
#
# Thread 9: JobStatus.RUNNING
#
# Thread 9: JobStatus.DONE
#
# Thread 10: JobStatus.RUNNING
# Thread 10 started
#
#
# Thread 10: JobStatus.DONE
# Thread 11 started
#
#
# Thread 11: JobStatus.RUNNING
#
# Thread 11: JobStatus.DONE
# Thread 12 started
#
#
# Thread 12: JobStatus.RUNNING
#
# Thread 12: JobStatus.DONE
# Thread 13 started
#
#
# Thread 13: JobStatus.RUNNING
#
# Thread 13: JobStatus.DONE
# Thread 14 started
#
# Thread 14: JobStatus.RUNNING
#
#
# Thread 14: JobStatus.DONE
# Thread 15 started
#
#
# Thread 15: JobStatus.DONE
# Thread 16 started
#
#
# Thread 16: JobStatus.RUNNING
#
# Thread 16: JobStatus.DONE
# Thread 17 started
#
#
# Thread 17: JobStatus.RUNNING
#
# Thread 17: JobStatus.DONE
# Thread 18 started
#
#
# Thread 18: JobStatus.DONE
# Thread 19 started
#
#
# Thread 19: JobStatus.RUNNING
#
# Thread 19: JobStatus.DONE
# Thread 20 started
#
#
# Thread 20: JobStatus.RUNNING
#
# Thread 20: JobStatus.DONE
# Thread 21 started
#
#
# Thread 21: JobStatus.RUNNING
#
# Thread 21: JobStatus.DONE
# Thread 22 started
#
# Thread 22: JobStatus.RUNNING
#
#
# Thread 22: JobStatus.DONE
# Thread 23 started
#
#
# Thread 23: JobStatus.RUNNING
#
# Thread 23: JobStatus.DONE
# Thread 24 started
#
#
# Thread 24: JobStatus.RUNNING
#
# Thread 24: JobStatus.DONE
# Thread 25 started
#
#
# Thread 25: JobStatus.RUNNING
#
# Thread 25: JobStatus.DONE
# Thread 26 started
#
#
# Thread 26: JobStatus.RUNNING
#
# Thread 26: JobStatus.DONE
# Thread 27 started
#
#
# Thread 27: JobStatus.RUNNING
#
# Thread 27: JobStatus.DONE
# Thread 28 started
#
#
# Thread 28: JobStatus.RUNNING
#
# Thread 28: JobStatus.DONE
# Thread 29 started
#
#
# Thread 29: JobStatus.RUNNING
#
# Thread 29: JobStatus.DONE
# Thread 30 started
#
#
# Thread 30: JobStatus.RUNNING
#
# Thread 30: JobStatus.DONE
# Thread 31 started
#
#
# Thread 31: JobStatus.RUNNING
#
# Thread 31: JobStatus.DONE
# Thread 32 started
#
# Thread 32: JobStatus.RUNNING
#
#
# Thread 32: JobStatus.DONE
#
# All threads are done.
#
# COUNTS:
# Thread 1: {'00': 2034, '01': 2086, '10': 2005, '11': 2067}
# Thread 2: {'00': 1993, '01': 2103, '10': 2108, '11': 1988}
# Thread 3: {'10': 8192}
# Thread 4: {'00': 2039, '01': 2078, '10': 2038, '11': 2037}
# Thread 5: {'00': 1977, '01': 2108, '10': 2024, '11': 2083}
# Thread 6: {'00': 1983, '01': 2023, '10': 2092, '11': 2094}
# Thread 7: {'00': 2066, '01': 1997, '10': 2072, '11': 2057}
# Thread 8: {'00': 2042, '01': 2045, '10': 2020, '11': 2085}
# Thread 9: {'00': 2011, '01': 2063, '10': 2037, '11': 2081}
# Thread 10: {'00': 2094, '01': 1992, '10': 2045, '11': 2061}
# Thread 11: {'00': 2014, '01': 2023, '10': 2020, '11': 2135}
# Thread 12: {'00': 2042, '01': 2024, '10': 2053, '11': 2073}
# Thread 13: {'00': 1940, '01': 2020, '10': 2053, '11': 2179}
# Thread 14: {'00': 2028, '01': 2055, '10': 2116, '11': 1993}
# Thread 15: {'00': 1953, '01': 2027, '10': 2076, '11': 2136}
# Thread 16: {'00': 2071, '01': 2045, '10': 1973, '11': 2103}
# Thread 17: {'00': 2066, '01': 2105, '10': 2063, '11': 1958}
# Thread 18: {'00': 2007, '01': 2092, '10': 2070, '11': 2023}
# Thread 19: {'00': 1984, '01': 2048, '10': 2096, '11': 2064}
# Thread 20: {'00': 2137, '01': 1977, '10': 2003, '11': 2075}
# Thread 21: {'00': 2011, '01': 2055, '10': 2075, '11': 2051}
# Thread 22: {'00': 2002, '01': 2116, '10': 2029, '11': 2045}
# Thread 23: {'00': 1949, '01': 2084, '10': 2086, '11': 2073}
# Thread 24: {'00': 2041, '01': 2114, '10': 2018, '11': 2019}
# Thread 25: {'00': 2050, '01': 2035, '10': 2048, '11': 2059}
# Thread 26: {'00': 2035, '01': 2028, '10': 2041, '11': 2088}
# Thread 27: {'00': 1975, '01': 2068, '10': 2079, '11': 2070}
# Thread 28: {'00': 2042, '01': 2099, '10': 2034, '11': 2017}
# Thread 29: {'00': 2094, '01': 2048, '10': 2078, '11': 1972}
# Thread 30: {'00': 2092, '01': 2029, '10': 1993, '11': 2078}
# Thread 31: {'00': 1992, '01': 1999, '10': 2121, '11': 2080}
# Thread 32: {'00': 2126, '01': 2033, '10': 2010, '11': 2023}
#
# EXECUTION TIMES:
# Thread 1: 0.08869719505310059 s
# Thread 2: 0.08364629745483398 s
# Thread 3: 0.07903647422790527 s
# Thread 4: 0.0936121940612793 s
# Thread 5: 0.09165549278259277 s
# Thread 6: 0.08499741554260254 s
# Thread 7: 0.08362030982971191 s
# Thread 8: 0.0809774398803711 s
# Thread 9: 0.0859675407409668 s
# Thread 10: 0.09590435028076172 s
# Thread 11: 0.08469581604003906 s
# Thread 12: 0.09099769592285156 s
# Thread 13: 0.07837915420532227 s
# Thread 14: 0.08545756340026855 s
# Thread 15: 0.07835602760314941 s
# Thread 16: 0.08815407752990723 s
# Thread 17: 0.09007644653320312 s
# Thread 18: 0.07778263092041016 s
# Thread 19: 0.08509445190429688 s
# Thread 20: 0.08365011215209961 s
# Thread 21: 0.09562826156616211 s
# Thread 22: 0.10016465187072754 s
# Thread 23: 0.0835413932800293 s
# Thread 24: 0.08335757255554199 s
# Thread 25: 0.1025536060333252 s
# Thread 26: 0.08477926254272461 s
# Thread 27: 0.09411168098449707 s
# Thread 28: 0.07776379585266113 s
# Thread 29: 0.08480048179626465 s
# Thread 30: 0.08428382873535156 s
# Thread 31: 0.08574128150939941 s
# Thread 32: 0.08344435691833496 s
#
# Longest execution time: 0.1025536060333252 s (in thread number 25)
#
# Winner item has been found in sub-problem number 3.
# Index in main database: 10.
# Expected index: 10.
#
# Grover's search has succeeded.
# ------------------------------------------------------------
# After 2 runs:
# Mean execution time: 0.10172832012176514 s
# Successes: 2
# Success rate: 100.0 %.
# ------------------------------------------------------------
#
#
#
# ------------------------ RUN 3 -----------------------------
#
# Thread 1 started
# Thread 1: JobStatus.RUNNING
#
# Thread 1: JobStatus.DONE
# Thread 2 started
#
#
# Thread 2: JobStatus.RUNNING
#
# Thread 2: JobStatus.DONE
# Thread 3 started
#
#
# Thread 3: JobStatus.RUNNING
#
# Thread 3: JobStatus.DONE
# Thread 4 started
#
# Thread 4: JobStatus.RUNNING
#
#
# Thread 4: JobStatus.DONE
# Thread 5 started
#
#
# Thread 5: JobStatus.RUNNING
#
# Thread 5: JobStatus.DONE
# Thread 6 started
#
#
# Thread 6: JobStatus.RUNNING
#
# Thread 6: JobStatus.DONE
# Thread 7 started
#
#
# Thread 7: JobStatus.RUNNING
#
# Thread 7: JobStatus.DONE
# Thread 8 started
#
#
# Thread 8: JobStatus.RUNNING
#
# Thread 8: JobStatus.DONE
# Thread 9 started
#
#
# Thread 9: JobStatus.RUNNING
#
# Thread 9: JobStatus.DONE
# Thread 10 started
#
#
# Thread 10: JobStatus.DONE
# Thread 11 started
#
# Thread 11: JobStatus.RUNNING
#
#
# Thread 11: JobStatus.DONE
# Thread 12 started
#
# Thread 12: JobStatus.RUNNING
#
#
# Thread 12: JobStatus.DONE
# Thread 13 started
#
#
# Thread 13: JobStatus.RUNNING
#
# Thread 13: JobStatus.DONE
# Thread 14 started
#
#
# Thread 14: JobStatus.RUNNING
#
# Thread 14: JobStatus.DONE
# Thread 15 started
#
#
# Thread 15: JobStatus.RUNNING
#
# Thread 15: JobStatus.DONE
# Thread 16 started
#
#
# Thread 16: JobStatus.RUNNING
#
# Thread 16: JobStatus.DONE
# Thread 17 started
#
#
# Thread 17: JobStatus.RUNNING
#
# Thread 17: JobStatus.DONE
# Thread 18 started
#
#
# Thread 18: JobStatus.RUNNING
#
# Thread 18: JobStatus.DONE
# Thread 19 started
#
# Thread 19: JobStatus.RUNNING
#
#
# Thread 19: JobStatus.DONE
# Thread 20 started
#
# Thread 20: JobStatus.RUNNING
#
#
# Thread 20: JobStatus.DONE
# Thread 21 started
#
#
# Thread 21: JobStatus.RUNNING
#
# Thread 21: JobStatus.DONE
# Thread 22 started
#
#
# Thread 22: JobStatus.RUNNING
#
# Thread 22: JobStatus.DONE
# Thread 23 started
#
#
# Thread 23: JobStatus.RUNNING
#
# Thread 23: JobStatus.DONE
# Thread 24 started
#
#
# Thread 24: JobStatus.RUNNING
#
# Thread 24: JobStatus.DONE
# Thread 25 started
#
#
# Thread 25: JobStatus.RUNNING
#
# Thread 25: JobStatus.DONE
# Thread 26 started
#
#
# Thread 26: JobStatus.RUNNING
#
# Thread 26: JobStatus.DONE
# Thread 27 started
#
#
# Thread 27: JobStatus.RUNNING
#
# Thread 27: JobStatus.DONE
# Thread 28 started
#
#
# Thread 28: JobStatus.RUNNING
#
# Thread 28: JobStatus.DONE
# Thread 29 started
#
#
# Thread 29: JobStatus.RUNNING
#
# Thread 29: JobStatus.DONE
# Thread 30 started
#
#
# Thread 30: JobStatus.RUNNING
#
# Thread 30: JobStatus.DONE
# Thread 31 started
#
#
# Thread 31: JobStatus.DONE
# Thread 32 started
#
#
# Thread 32: JobStatus.RUNNING
#
# Thread 32: JobStatus.DONE
#
# All threads are done.
#
# COUNTS:
# Thread 1: {'00': 2038, '01': 2054, '10': 2085, '11': 2015}
# Thread 2: {'00': 2059, '01': 2038, '10': 2077, '11': 2018}
# Thread 3: {'10': 8192}
# Thread 4: {'00': 2072, '01': 2047, '10': 2043, '11': 2030}
# Thread 5: {'00': 2059, '01': 2080, '10': 2054, '11': 1999}
# Thread 6: {'00': 2139, '01': 2053, '10': 2027, '11': 1973}
# Thread 7: {'00': 1977, '01': 2065, '10': 2101, '11': 2049}
# Thread 8: {'00': 2053, '01': 2106, '10': 1995, '11': 2038}
# Thread 9: {'00': 2056, '01': 2083, '10': 2023, '11': 2030}
# Thread 10: {'00': 2003, '01': 2057, '10': 2098, '11': 2034}
# Thread 11: {'00': 2008, '01': 2012, '10': 2077, '11': 2095}
# Thread 12: {'00': 2057, '01': 2095, '10': 2038, '11': 2002}
# Thread 13: {'00': 2034, '01': 2090, '10': 2028, '11': 2040}
# Thread 14: {'00': 2048, '01': 2010, '10': 2078, '11': 2056}
# Thread 15: {'00': 2094, '01': 2039, '10': 2038, '11': 2021}
# Thread 16: {'00': 2018, '01': 2062, '10': 2094, '11': 2018}
# Thread 17: {'00': 2017, '01': 2061, '10': 1998, '11': 2116}
# Thread 18: {'00': 2077, '01': 2027, '10': 2079, '11': 2009}
# Thread 19: {'00': 2009, '01': 2054, '10': 2042, '11': 2087}
# Thread 20: {'00': 2044, '01': 2021, '10': 2035, '11': 2092}
# Thread 21: {'00': 2045, '01': 1994, '10': 2138, '11': 2015}
# Thread 22: {'00': 2110, '01': 2045, '10': 1997, '11': 2040}
# Thread 23: {'00': 2025, '01': 2137, '10': 1997, '11': 2033}
# Thread 24: {'00': 2042, '01': 2056, '10': 2016, '11': 2078}
# Thread 25: {'00': 2100, '01': 2007, '10': 2039, '11': 2046}
# Thread 26: {'00': 2050, '01': 2020, '10': 2045, '11': 2077}
# Thread 27: {'00': 2073, '01': 2042, '10': 2086, '11': 1991}
# Thread 28: {'00': 1989, '01': 2082, '10': 2104, '11': 2017}
# Thread 29: {'00': 2029, '01': 2017, '10': 2135, '11': 2011}
# Thread 30: {'00': 2085, '01': 2055, '10': 2081, '11': 1971}
# Thread 31: {'00': 2006, '01': 2063, '10': 2023, '11': 2100}
# Thread 32: {'00': 2042, '01': 2062, '10': 1974, '11': 2114}
#
# EXECUTION TIMES:
# Thread 1: 0.08370065689086914 s
# Thread 2: 0.10124945640563965 s
# Thread 3: 0.08974909782409668 s
# Thread 4: 0.07855677604675293 s
# Thread 5: 0.07824540138244629 s
# Thread 6: 0.09023857116699219 s
# Thread 7: 0.08042359352111816 s
# Thread 8: 0.0818474292755127 s
# Thread 9: 0.09509825706481934 s
# Thread 10: 0.07714343070983887 s
# Thread 11: 0.0839686393737793 s
# Thread 12: 0.0802149772644043 s
# Thread 13: 0.08515667915344238 s
# Thread 14: 0.07994961738586426 s
# Thread 15: 0.07901191711425781 s
# Thread 16: 0.0784764289855957 s
# Thread 17: 0.07844090461730957 s
# Thread 18: 0.10046648979187012 s
# Thread 19: 0.09372496604919434 s
# Thread 20: 0.08287477493286133 s
# Thread 21: 0.08143162727355957 s
# Thread 22: 0.10014057159423828 s
# Thread 23: 0.08790898323059082 s
# Thread 24: 0.0992119312286377 s
# Thread 25: 0.09190678596496582 s
# Thread 26: 0.1045842170715332 s
# Thread 27: 0.08428001403808594 s
# Thread 28: 0.08302426338195801 s
# Thread 29: 0.08837556838989258 s
# Thread 30: 0.09676599502563477 s
# Thread 31: 0.0801553726196289 s
# Thread 32: 0.08831548690795898 s
#
# Longest execution time: 0.1045842170715332 s (in thread number 26)
#
# Winner item has been found in sub-problem number 3.
# Index in main database: 10.
# Expected index: 10.
#
# Grover's search has succeeded.
# ------------------------------------------------------------
# After 3 runs:
# Mean execution time: 0.10268028577168782 s
# Successes: 3
# Success rate: 100.0 %.
# ------------------------------------------------------------
#
#
#
# ------------------------ RUN 4 -----------------------------
#
# Thread 1 started
#
#
# Thread 1: JobStatus.RUNNING
#
# Thread 1: JobStatus.DONE
# Thread 2 started
#
#
# Thread 2: JobStatus.RUNNING
#
# Thread 2: JobStatus.DONE
# Thread 3 started
#
#
# Thread 3: JobStatus.RUNNING
#
# Thread 3: JobStatus.DONE
# Thread 4 started
#
#
# Thread 4: JobStatus.RUNNING
#
# Thread 4: JobStatus.DONE
#
# Thread 5: JobStatus.RUNNING
# Thread 5 started
#
#
# Thread 5: JobStatus.DONE
#
# Thread 6: JobStatus.RUNNINGThread 6 started
#
#
#
# Thread 6: JobStatus.DONE
# Thread 7 started
#
#
# Thread 7: JobStatus.RUNNING
#
# Thread 7: JobStatus.DONE
# Thread 8 started
#
#
# Thread 8: JobStatus.RUNNING
#
# Thread 8: JobStatus.DONE
# Thread 9 started
#
#
# Thread 9: JobStatus.RUNNING
#
# Thread 9: JobStatus.DONE
# Thread 10 started
#
#
# Thread 10: JobStatus.RUNNING
#
# Thread 10: JobStatus.DONE
# Thread 11 started
#
#
# Thread 11: JobStatus.RUNNING
#
# Thread 11: JobStatus.DONE
# Thread 12 started
#
#
# Thread 12: JobStatus.RUNNING
#
# Thread 12: JobStatus.DONE
# Thread 13 started
#
#
# Thread 13: JobStatus.RUNNING
#
# Thread 13: JobStatus.DONE
# Thread 14 started
#
#
# Thread 14: JobStatus.RUNNING
#
# Thread 14: JobStatus.DONE
# Thread 15 started
#
# Thread 15: JobStatus.RUNNING
#
#
# Thread 15: JobStatus.DONE
# Thread 16 started
#
#
# Thread 16: JobStatus.RUNNING
#
# Thread 16: JobStatus.DONE
# Thread 17 started
#
#
# Thread 17: JobStatus.RUNNING
#
# Thread 17: JobStatus.DONE
# Thread 18 started
#
#
# Thread 18: JobStatus.RUNNING
#
# Thread 18: JobStatus.DONE
# Thread 19 started
#
#
# Thread 19: JobStatus.RUNNING
#
# Thread 19: JobStatus.DONE
# Thread 20 started
#
#
# Thread 20: JobStatus.RUNNING
#
# Thread 20: JobStatus.DONE
# Thread 21 started
#
# Thread 21: JobStatus.DONE
#
# Thread 22 started
#
#
# Thread 22: JobStatus.DONE
# Thread 23 started
#
#
# Thread 23: JobStatus.RUNNING
#
# Thread 23: JobStatus.DONE
# Thread 24 started
#
#
# Thread 24: JobStatus.RUNNING
#
# Thread 24: JobStatus.DONE
# Thread 25 started
#
#
# Thread 25: JobStatus.RUNNING
#
# Thread 25: JobStatus.DONE
# Thread 26 started
#
#
# Thread 26: JobStatus.DONE
# Thread 27 started
#
#
# Thread 27: JobStatus.RUNNING
#
# Thread 27: JobStatus.DONE
# Thread 28 started
#
#
# Thread 28: JobStatus.RUNNING
#
# Thread 28: JobStatus.DONE
# Thread 29 started
#
#
# Thread 29: JobStatus.RUNNING
#
# Thread 29: JobStatus.DONE
# Thread 30 started
#
#
# Thread 30: JobStatus.RUNNING
#
# Thread 30: JobStatus.DONE
# Thread 31 started
#
#
# Thread 31: JobStatus.DONE
# Thread 32 started
#
#
# Thread 32: JobStatus.RUNNING
#
# Thread 32: JobStatus.DONE
#
# All threads are done.
#
# COUNTS:
# Thread 1: {'00': 2095, '01': 2024, '10': 2053, '11': 2020}
# Thread 2: {'00': 2006, '01': 2074, '10': 2002, '11': 2110}
# Thread 3: {'10': 8192}
# Thread 4: {'00': 2006, '01': 2079, '10': 2085, '11': 2022}
# Thread 5: {'00': 2046, '01': 2055, '10': 2071, '11': 2020}
# Thread 6: {'00': 2125, '01': 1987, '10': 1986, '11': 2094}
# Thread 7: {'00': 2053, '01': 1950, '10': 2106, '11': 2083}
# Thread 8: {'00': 2011, '01': 2071, '10': 2050, '11': 2060}
# Thread 9: {'00': 2073, '01': 2056, '10': 2067, '11': 1996}
# Thread 10: {'00': 2023, '01': 2045, '10': 2043, '11': 2081}
# Thread 11: {'00': 2108, '01': 1957, '10': 2047, '11': 2080}
# Thread 12: {'00': 2020, '01': 2042, '10': 2108, '11': 2022}
# Thread 13: {'00': 2029, '01': 2081, '10': 2065, '11': 2017}
# Thread 14: {'00': 2027, '01': 2131, '10': 2034, '11': 2000}
# Thread 15: {'00': 2078, '01': 2063, '10': 1928, '11': 2123}
# Thread 16: {'00': 2109, '01': 2065, '10': 2054, '11': 1964}
# Thread 17: {'00': 2018, '01': 2101, '10': 2051, '11': 2022}
# Thread 18: {'00': 1938, '01': 2096, '10': 2091, '11': 2067}
# Thread 19: {'00': 2021, '01': 2081, '10': 2071, '11': 2019}
# Thread 20: {'00': 2030, '01': 2063, '10': 2070, '11': 2029}
# Thread 21: {'00': 2063, '01': 2017, '10': 2049, '11': 2063}
# Thread 22: {'00': 1959, '01': 2152, '10': 2048, '11': 2033}
# Thread 23: {'00': 1990, '01': 2089, '10': 1982, '11': 2131}
# Thread 24: {'00': 2040, '01': 2035, '10': 2094, '11': 2023}
# Thread 25: {'00': 2077, '01': 2042, '10': 1996, '11': 2077}
# Thread 26: {'00': 2037, '01': 2036, '10': 2053, '11': 2066}
# Thread 27: {'00': 1997, '01': 2064, '10': 2119, '11': 2012}
# Thread 28: {'00': 1961, '01': 2114, '10': 2036, '11': 2081}
# Thread 29: {'00': 2050, '01': 2038, '10': 2036, '11': 2068}
# Thread 30: {'00': 2111, '01': 2028, '10': 2066, '11': 1987}
# Thread 31: {'00': 2046, '01': 2062, '10': 2064, '11': 2020}
# Thread 32: {'00': 1983, '01': 2081, '10': 2102, '11': 2026}
#
# EXECUTION TIMES:
# Thread 1: 0.07829403877258301 s
# Thread 2: 0.08586835861206055 s
# Thread 3: 0.08324289321899414 s
# Thread 4: 0.09726929664611816 s
# Thread 5: 0.0894780158996582 s
# Thread 6: 0.08362650871276855 s
# Thread 7: 0.08795976638793945 s
# Thread 8: 0.0834665298461914 s
# Thread 9: 0.09577345848083496 s
# Thread 10: 0.09256339073181152 s
# Thread 11: 0.07826972007751465 s
# Thread 12: 0.08395028114318848 s
# Thread 13: 0.08276152610778809 s
# Thread 14: 0.09035277366638184 s
# Thread 15: 0.08427977561950684 s
# Thread 16: 0.0827028751373291 s
# Thread 17: 0.085540771484375 s
# Thread 18: 0.07920145988464355 s
# Thread 19: 0.0831289291381836 s
# Thread 20: 0.08728241920471191 s
# Thread 21: 0.07854628562927246 s
# Thread 22: 0.07833456993103027 s
# Thread 23: 0.08361029624938965 s
# Thread 24: 0.08647608757019043 s
# Thread 25: 0.07917165756225586 s
# Thread 26: 0.08022189140319824 s
# Thread 27: 0.08783555030822754 s
# Thread 28: 0.08737063407897949 s
# Thread 29: 0.0847322940826416 s
# Thread 30: 0.08345723152160645 s
# Thread 31: 0.07892966270446777 s
# Thread 32: 0.07981348037719727 s
#
# Longest execution time: 0.09726929664611816 s (in thread number 4)
#
# Winner item has been found in sub-problem number 3.
# Index in main database: 10.
# Expected index: 10.
#
# Grover's search has succeeded.
# ------------------------------------------------------------
# After 4 runs:
# Mean execution time: 0.10132753849029541 s
# Successes: 4
# Success rate: 100.0 %.
# ------------------------------------------------------------
#
#
#
# ------------------------ RUN 5 -----------------------------
# Thread 1 started
#
#
# Thread 1: JobStatus.RUNNING
#
# Thread 1: JobStatus.DONE
# Thread 2 started
#
#
# Thread 2: JobStatus.RUNNING
#
# Thread 2: JobStatus.DONE
# Thread 3 started
#
#
# Thread 3: JobStatus.RUNNING
#
# Thread 3: JobStatus.DONE
# Thread 4 started
#
#
# Thread 4: JobStatus.RUNNING
#
# Thread 4: JobStatus.DONE
# Thread 5 started
#
#
# Thread 5: JobStatus.RUNNING
#
# Thread 5: JobStatus.DONE
# Thread 6 started
#
#
# Thread 6: JobStatus.RUNNING
#
# Thread 6: JobStatus.DONE
#
# Thread 7: JobStatus.RUNNING
# Thread 7 started
#
#
# Thread 7: JobStatus.DONE
# Thread 8 started
#
#
# Thread 8: JobStatus.RUNNING
#
# Thread 8: JobStatus.DONE
# Thread 9 started
#
#
# Thread 9: JobStatus.RUNNING
#
# Thread 9: JobStatus.DONE
# Thread 10 started
#
#
# Thread 10: JobStatus.RUNNING
#
# Thread 10: JobStatus.DONE
# Thread 11 started
#
#
# Thread 11: JobStatus.RUNNING
#
# Thread 11: JobStatus.DONE
# Thread 12 started
#
#
# Thread 12: JobStatus.RUNNING
#
# Thread 12: JobStatus.DONE
# Thread 13 started
#
#
# Thread 13: JobStatus.RUNNING
#
# Thread 13: JobStatus.DONE
# Thread 14 started
#
#
# Thread 14: JobStatus.RUNNING
#
# Thread 14: JobStatus.DONE
# Thread 15 started
#
#
# Thread 15: JobStatus.RUNNING
#
# Thread 15: JobStatus.DONE
# Thread 16 started
#
#
# Thread 16: JobStatus.RUNNING
#
# Thread 16: JobStatus.DONE
# Thread 17 started
#
#
# Thread 17: JobStatus.RUNNING
#
# Thread 17: JobStatus.DONE
# Thread 18 started
#
#
# Thread 18: JobStatus.RUNNING
#
# Thread 18: JobStatus.DONE
# Thread 19 started
#
#
# Thread 19: JobStatus.RUNNING
#
# Thread 19: JobStatus.DONE
# Thread 20 started
#
#
# Thread 20: JobStatus.RUNNING
#
# Thread 20: JobStatus.DONE
# Thread 21 started
#
#
# Thread 21: JobStatus.RUNNING
#
# Thread 21: JobStatus.DONE
# Thread 22 started
#
#
# Thread 22: JobStatus.RUNNING
#
# Thread 22: JobStatus.DONE
# Thread 23 started
#
#
# Thread 23: JobStatus.RUNNING
#
# Thread 23: JobStatus.DONE
# Thread 24 started
#
# Thread 24: JobStatus.RUNNING
#
#
# Thread 24: JobStatus.DONE
# Thread 25 started
#
#
# Thread 25: JobStatus.RUNNING
#
# Thread 25: JobStatus.DONE
# Thread 26 started
#
# Thread 26: JobStatus.RUNNING
#
#
# Thread 26: JobStatus.DONE
# Thread 27 started
#
#
# Thread 27: JobStatus.RUNNING
#
# Thread 27: JobStatus.DONE
# Thread 28 started
#
#
# Thread 28: JobStatus.RUNNING
#
# Thread 28: JobStatus.DONE
# Thread 29 started
#
#
# Thread 29: JobStatus.DONE
# Thread 30 started
#
#
# Thread 30: JobStatus.RUNNING
#
# Thread 30: JobStatus.DONE
# Thread 31 started
#
#
# Thread 31: JobStatus.RUNNING
#
# Thread 31: JobStatus.DONE
# Thread 32 started
#
#
# Thread 32: JobStatus.RUNNING
#
# Thread 32: JobStatus.DONE
#
# All threads are done.
#
# COUNTS:
# Thread 1: {'00': 2068, '01': 2014, '10': 2089, '11': 2021}
# Thread 2: {'00': 2067, '01': 2046, '10': 2039, '11': 2040}
# Thread 3: {'10': 8192}
# Thread 4: {'00': 2100, '01': 2021, '10': 2033, '11': 2038}
# Thread 5: {'00': 2022, '01': 2085, '10': 2041, '11': 2044}
# Thread 6: {'00': 2095, '01': 2022, '10': 2028, '11': 2047}
# Thread 7: {'00': 2003, '01': 2097, '10': 2056, '11': 2036}
# Thread 8: {'00': 2076, '01': 1996, '10': 2026, '11': 2094}
# Thread 9: {'00': 2050, '01': 2113, '10': 2033, '11': 1996}
# Thread 10: {'00': 2048, '01': 2083, '10': 1981, '11': 2080}
# Thread 11: {'00': 2040, '01': 2075, '10': 2002, '11': 2075}
# Thread 12: {'00': 2098, '01': 2004, '10': 2029, '11': 2061}
# Thread 13: {'00': 2074, '01': 2076, '10': 2010, '11': 2032}
# Thread 14: {'00': 2068, '01': 2041, '10': 2018, '11': 2065}
# Thread 15: {'00': 2024, '01': 2040, '10': 2088, '11': 2040}
# Thread 16: {'00': 2058, '01': 2023, '10': 2072, '11': 2039}
# Thread 17: {'00': 2110, '01': 2060, '10': 2079, '11': 1943}
# Thread 18: {'00': 2007, '01': 2058, '10': 2079, '11': 2048}
# Thread 19: {'00': 2037, '01': 1978, '10': 2064, '11': 2113}
# Thread 20: {'00': 2004, '01': 2041, '10': 2095, '11': 2052}
# Thread 21: {'00': 2074, '01': 2065, '10': 2025, '11': 2028}
# Thread 22: {'00': 2051, '01': 2080, '10': 1987, '11': 2074}
# Thread 23: {'00': 2004, '01': 1979, '10': 2173, '11': 2036}
# Thread 24: {'00': 2044, '01': 2076, '10': 1990, '11': 2082}
# Thread 25: {'00': 2057, '01': 2075, '10': 2045, '11': 2015}
# Thread 26: {'00': 2055, '01': 2032, '10': 2109, '11': 1996}
# Thread 27: {'00': 2022, '01': 2055, '10': 2042, '11': 2073}
# Thread 28: {'00': 2080, '01': 2050, '10': 2073, '11': 1989}
# Thread 29: {'00': 2121, '01': 2061, '10': 1999, '11': 2011}
# Thread 30: {'00': 2080, '01': 2113, '10': 2019, '11': 1980}
# Thread 31: {'00': 2056, '01': 2065, '10': 2048, '11': 2023}
# Thread 32: {'00': 2092, '01': 2012, '10': 1992, '11': 2096}
#
# EXECUTION TIMES:
# Thread 1: 0.08371543884277344 s
# Thread 2: 0.08573627471923828 s
# Thread 3: 0.0837392807006836 s
# Thread 4: 0.08879566192626953 s
# Thread 5: 0.08414268493652344 s
# Thread 6: 0.08526396751403809 s
# Thread 7: 0.10045886039733887 s
# Thread 8: 0.0853729248046875 s
# Thread 9: 0.08363795280456543 s
# Thread 10: 0.09612894058227539 s
# Thread 11: 0.0848541259765625 s
# Thread 12: 0.08488082885742188 s
# Thread 13: 0.0840144157409668 s
# Thread 14: 0.08731746673583984 s
# Thread 15: 0.0879063606262207 s
# Thread 16: 0.08365106582641602 s
# Thread 17: 0.08456945419311523 s
# Thread 18: 0.0791628360748291 s
# Thread 19: 0.08892703056335449 s
# Thread 20: 0.0892801284790039 s
# Thread 21: 0.08560872077941895 s
# Thread 22: 0.08314728736877441 s
# Thread 23: 0.09563493728637695 s
# Thread 24: 0.0830988883972168 s
# Thread 25: 0.08641314506530762 s
# Thread 26: 0.08353877067565918 s
# Thread 27: 0.09137988090515137 s
# Thread 28: 0.08415031433105469 s
# Thread 29: 0.08025002479553223 s
# Thread 30: 0.08488845825195312 s
# Thread 31: 0.09081625938415527 s
# Thread 32: 0.09576988220214844 s
#
# Longest execution time: 0.10045886039733887 s (in thread number 7)
#
# Winner item has been found in sub-problem number 3.
# Index in main database: 10.
# Expected index: 10.
#
# Grover's search has succeeded.
# ------------------------------------------------------------
# After 5 runs:
# Mean execution time: 0.1011538028717041 s
# Successes: 5
# Success rate: 100.0 %.
# ------------------------------------------------------------

# %% [markdown]
# In the output of the above cell, it can be seen the success rate of the Distributed Grover's Algorithm. Moreover, during the execution indications about the status of each thread and the counts obtaining at the end of each sub-search are given.
